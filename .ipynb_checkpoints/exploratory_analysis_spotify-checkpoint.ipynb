# %% [markdown]
# # Spotify Data
# - An exploration of general Spotify data as practise for data analysis
# - Analysis and visualisation where possible of my own personal 'Your Top Songs' playlists.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('/users/aoifesullivan/Downloads/dataset.csv')
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#    Unnamed: 0                track_id                               artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV                           Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A                          Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b                Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx                          Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 5           5  01MVOl9KtVTNfFiBU9I7dc                          Tyrone Wells
# 6           6  6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
# 7           7  1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 8           8  0IktbUcnAGrvD03AWnz3Q8             Jason Mraz;Colbie Caillat
# 9           9  7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
# 5                               Days I Will Remember
# 6                        Is There Anybody Out There?
# 7                We Sing. We Dance. We Steal Things.
# 8                We Sing. We Dance. We Steal Things.
# 9                                             Hunger
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
# 5        Days I Will Remember          58       214240     False
# 6               Say Something          74       229400     False
# 7                   I'm Yours          80       242946     False
# 8                       Lucky          74       189613     False
# 9                      Hunger          56       205594     False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430    2    -9.681     1       0.0526        0.4690
# 5         0.688  0.4810    6    -8.807     1       0.1050        0.2890
# 6         0.407  0.1470    2    -8.822     1       0.0355        0.8570
# 7         0.703  0.4440   11    -9.331     1       0.0417        0.5590
# 8         0.625  0.4140    0    -8.700     1       0.0369        0.2940
# 9         0.442  0.6320    1    -6.770     1       0.0295        0.4260
#
#    instrumentalness  liveness  valence    tempo  time_signature track_genre
# 0          0.000001    0.3580   0.7150   87.917               4    acoustic
# 1          0.000006    0.1010   0.2670   77.489               4    acoustic
# 2          0.000000    0.1170   0.1200   76.332               4    acoustic
# 3          0.000071    0.1320   0.1430  181.740               3    acoustic
# 4          0.000000    0.0829   0.1670  119.949               4    acoustic
# 5          0.000000    0.1890   0.6660   98.017               4    acoustic
# 6          0.000003    0.0913   0.0765  141.284               3    acoustic
# 7          0.000000    0.0973   0.7120  150.960               4    acoustic
# 8          0.000000    0.1510   0.6690  130.088               4    acoustic
# 9          0.004190    0.0735   0.1960   78.899               4    acoustic

# %%
df.groupby('track_genre')

# %%
df.track_genre.value_counts()
# Out:
# acoustic             1000
# punk-rock            1000
# progressive-house    1000
# power-pop            1000
# pop                  1000
#                      ...
# folk                 1000
# emo                  1000
# electronic           1000
# electro              1000
# world-music          1000
# Name: track_genre, Length: 114, dtype: int64

# %%
df.loc[df.explicit==True].track_genre.value_counts()
# Out:
# comedy      656
# emo         465
# sad         450
# j-dance     391
# hardcore    325
#            ...
# guitar        2
# pop-film      1
# opera         1
# j-idol        1
# disney        1
# Name: track_genre, Length: 106, dtype: int64

# %%
df.shape
# Out:
# (114000, 21)

# %%
#just the length of the data set for percentages or whatever
df_count = df.shape[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
#  16  liveness          114000 non-null  float64
#  17  valence           114000 non-null  float64
#  18  tempo             114000 non-null  float64
#  19  time_signature    114000 non-null  int64
#  20  track_genre       114000 non-null  object
# dtypes: bool(1), float64(9), int64(6), object(5)
# memory usage: 17.5+ MB

# %% [markdown]
# *A few ideas of things to work out:*
# - Top 10 most popular tracks
# - Top 10 most popular artists
# - Top 10 most popular genres
# - Correlation btween danceability and energy
# - Least popular songs graphed by genre
# - Most common time signature - graph it by frequency
# - Explicit vs non explicit percent - most and least explicit genre

# %%
#pd.isna(df) #boolean masks if there are nulls or not
#pd.isna(df).sum() # shows the columns where the nulls are
pd.isna(df).sum().sum() #shows the total number of all missing values in the dataset, which is 3.
# Out:
# 3

# %%
#How many unique artists are there
artists = df[['artists']]
artists
# Out:
#                        artists
# 0                  Gen Hoshino
# 1                 Ben Woodward
# 2       Ingrid Michaelson;ZAYN
# 3                 Kina Grannis
# 4             Chord Overstreet
# ...                        ...
# 113995           Rainy Lullaby
# 113996           Rainy Lullaby
# 113997           Cesária Evora
# 113998        Michael W. Smith
# 113999           Cesária Evora
#
# [114000 rows x 1 columns]

# %%
#Preview of all the genres, out of interest
df['track_genre'].unique()
# Out:
# array(['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient',
#        'anime', 'black-metal', 'bluegrass', 'blues', 'brazil',
#        'breakbeat', 'british', 'cantopop', 'chicago-house', 'children',
#        'chill', 'classical', 'club', 'comedy', 'country', 'dance',
#        'dancehall', 'death-metal', 'deep-house', 'detroit-techno',
#        'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm',
#        'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk',
#        'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove',
#        'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle',
#        'heavy-metal', 'hip-hop', 'honky-tonk', 'house', 'idm', 'indian',
#        'indie-pop', 'indie', 'industrial', 'iranian', 'j-dance', 'j-idol',
#        'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino',
#        'malay', 'mandopop', 'metal', 'metalcore', 'minimal-techno', 'mpb',
#        'new-age', 'opera', 'pagode', 'party', 'piano', 'pop-film', 'pop',
#        'power-pop', 'progressive-house', 'psych-rock', 'punk-rock',
#        'punk', 'r-n-b', 'reggae', 'reggaeton', 'rock-n-roll', 'rock',
#        'rockabilly', 'romance', 'sad', 'salsa', 'samba', 'sertanejo',
#        'show-tunes', 'singer-songwriter', 'ska', 'sleep', 'songwriter',
#        'soul', 'spanish', 'study', 'swedish', 'synth-pop', 'tango',
#        'techno', 'trance', 'trip-hop', 'turkish', 'world-music'],
#       dtype=object)

# %%
# Most frequently seen artist in df
artists.value_counts()
# Out:
# artists
# The Beatles                 279
# George Jones                271
# Stevie Wonder               236
# Linkin Park                 224
# Ella Fitzgerald             222
#                            ...
# Mother Love Bone              1
# DubVision;Afrojack            1
# Dub Pistols;Too Many T's      1
# Mothership                    1
# DJ Mongoose                   1
# Length: 31437, dtype: int64

# %% [markdown]
# ## Explicit content exploration.
# Covering the following:
# 1. Total tracks in the dataset : 114000
# 2. Total tracks that are explicit : 9747
# 3. Total percent of tracks that are explicit: 8.55%
# 4. Total percent of tracks that are explicit by genre: under the variable most_explicit_order as a series
# 5. Most explicit genre: Comedy (with 65.6% of tracks being explicit)
# 6. How many genres have no instances of being explicit in the df: 8
# 7. List of genres that have no instances of being explicit: ['children', 'classical', 'gospel', 'honky-tonk', 'sleep', 'study','tango', 'world-music']
# 8. List of genres that are more explicit than total across all genres (bonus if you can be bothered to attempt to chart them)

# %%
#1. 

#How many tracks are there in total
df.shape
# Out:
# (114000, 21)

# %%
# Markus Version of Bla
df['explicit'].value_counts()[True]
# Out:
# 9747

# %%
# Markus Version of Bla
df['explicit'].value_counts()
# Out:
# False    104253
# True       9747
# Name: explicit, dtype: int64

# %%
#2.

#How many tracks are explicit
filt = df['explicit'] == True
explicit = df.loc[filt, 'explicit']
count_explicit = explicit.value_counts().item()
count_explicit
# Out:
# 9747

# %%
#3.

#Total percent of tracks that are explicit
total_percent_explicit = (count_explicit / df_count) * 100
#total_percent_explicit.dtype
total_percent_explicit
# Out:
# 8.55

# %% [markdown]
# How many tracks are explicit compared to the total amount - percentage

# %%
#create a filter to pull only rows that are counted as explicit
only_explicit = df.loc[filt]

# %%
#Make 2 groupbys, one is for grouping by genre, one is for grouping by genre with the explicit only filter

groupby_genre = df.groupby(['track_genre'])
explicit_groupby_genre = only_explicit.groupby(['track_genre'])
groupby_genre.head(10)
# Out:
#         Unnamed: 0                track_id  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV
# 1                1  4qPNDBW1i3p13qLCt0Ki3A
# 2                2  1iJBSr7s7jYXzM8EGcbK5b
# 3                3  6lfxq3CG4xtTiEg7opyCyx
# 4                4  5vjLSffimiIP26QG5WcN2K
# ...            ...                     ...
# 113005      113005  40lKptao1hxVqA7fd1OOGp
# 113006      113006  6aRwLqDf1bN3lI2gMd6wXp
# 113007      113007  1QoQC9g6R0K1SrPQifxaWB
# 113008      113008  4ElNxglBjcrASiGn58t9Jm
# 113009      113009  35WtFQK3iG2WPjstuuKaVc
#
#                                    artists  \
# 0                              Gen Hoshino
# 1                             Ben Woodward
# 2                   Ingrid Michaelson;ZAYN
# 3                             Kina Grannis
# 4                         Chord Overstreet
# ...                                    ...
# 113005                        Chris Tomlin
# 113006           Passion;Kristian Stanfill
# 113007  Hillsong Worship;Brooke Ligertwood
# 113008                  for KING & COUNTRY
# 113009               Hillsong Worship;TAYA
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                 Hold On
# ...                                                   ...
# 113005                        And If Our God Is For Us...
# 113006                      Passion: Let The Future Begin
# 113007                                   Who You Say I Am
# 113008                                     Burn The Ships
# 113009                                      No Other Name
#
#                             track_name  popularity  duration_ms  explicit  \
# 0                               Comedy          73       230666     False
# 1                     Ghost - Acoustic          55       149610     False
# 2                       To Begin Again          57       210826     False
# 3           Can't Help Falling In Love          71       201933     False
# 4                              Hold On          82       198853     False
# ...                                ...         ...          ...       ...
# 113005                         Our God          63       285160     False
# 113006          In Christ Alone - Live          57       339493     False
# 113007                Who You Say I Am          56       198704     False
# 113008                  God Only Knows          64       229760     False
# 113009  Broken Vessels (Amazing Grace)          63       568791     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.676  0.4610    1    -6.746     0       0.1430       0.03220
# 1              0.420  0.1660    1   -17.235     1       0.0763       0.92400
# 2              0.438  0.3590    0    -9.734     1       0.0557       0.21000
# 3              0.266  0.0596    0   -18.515     1       0.0363       0.90500
# 4              0.618  0.4430    2    -9.681     1       0.0526       0.46900
# ...              ...     ...  ...       ...   ...          ...           ...
# 113005         0.509  0.7780   11    -3.608     1       0.0295       0.00998
# 113006         0.378  0.5960    5    -5.406     1       0.0323       0.01820
# 113007         0.377  0.6440    6    -8.139     1       0.0404       0.00410
# 113008         0.597  0.4170    2    -7.952     1       0.0502       0.39500
# 113009         0.379  0.4890    7    -7.051     1       0.0281       0.29300
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 0               0.000001    0.3580   0.7150   87.917               4
# 1               0.000006    0.1010   0.2670   77.489               4
# 2               0.000000    0.1170   0.1200   76.332               4
# 3               0.000071    0.1320   0.1430  181.740               3
# 4               0.000000    0.0829   0.1670  119.949               4
# ...                  ...       ...      ...      ...             ...
# 113005          0.000000    0.1900   0.2160  105.066               4
# 113006          0.000011    0.1440   0.1720  135.968               3
# 113007          0.000000    0.0890   0.2990  171.908               3
# 113008          0.000008    0.1280   0.2630  143.839               4
# 113009          0.000009    0.7210   0.0871  140.937               4
#
#         track_genre
# 0          acoustic
# 1          acoustic
# 2          acoustic
# 3          acoustic
# 4          acoustic
# ...             ...
# 113005  world-music
# 113006  world-music
# 113007  world-music
# 113008  world-music
# 113009  world-music
#
# [1140 rows x 21 columns]

# %%
track_count_by_genre = groupby_genre.size()
track_count_by_genre.sort_values(ascending = False)
# Out:
# track_genre
# acoustic             1000
# punk                 1000
# progressive-house    1000
# power-pop            1000
# pop-film             1000
#                      ...
# folk                 1000
# emo                  1000
# electronic           1000
# electro              1000
# world-music          1000
# Length: 114, dtype: int64

# %%
explicit_track_count_by_genre = explicit_groupby_genre.size()
explicit_track_count_by_genre.sort_values(ascending = False)
# Out:
# track_genre
# comedy      656
# emo         465
# sad         450
# j-dance     391
# hardcore    325
#            ...
# cantopop      2
# opera         1
# disney        1
# pop-film      1
# j-idol        1
# Length: 106, dtype: int64

# %%
#This
df.groupby(['track_genre', 'explicit']).size()
#and this
explicit_by_genre = groupby_genre['explicit'].value_counts()
explicit_by_genre
#seem to serve the same purpose, except 2nd one hasa variable
# Out:
# track_genre  explicit
# acoustic     False        948
#              True          52
# afrobeat     False        982
#              True          18
# alt-rock     False        944
#                          ...
# trip-hop     False        955
#              True          45
# turkish      False        782
#              True         218
# world-music  False       1000
# Name: explicit, Length: 220, dtype: int64

# %% [markdown]
# So now I knw the most explicit is comedy, and the many least are tango, sleep etc.

# %%
#4.

#Total percent of tracks that are explicit by genre

explicit_percent = explicit_track_count_by_genre / track_count_by_genre * 100
most_explicit_order = explicit_percent.sort_values(ascending = False)
most_explicit_order.head(50)
# Out:
# track_genre
# comedy         65.6
# emo            46.5
# sad            45.0
# j-dance        39.1
# hardcore       32.5
# hip-hop        31.9
# funk           30.4
# dancehall      30.2
# metalcore      29.1
# death-metal    25.1
# latino         24.9
# industrial     23.6
# french         21.9
# turkish        21.8
# reggaeton      21.2
# dance          17.4
# chill          17.1
# reggae         16.7
# alternative    16.4
# electro        15.3
# grindcore      15.3
# metal          14.2
# latin          13.3
# black-metal    13.1
# german         12.7
# happy          12.6
# electronic     12.0
# house          10.7
# indie-pop      10.7
# edm            10.6
# punk           10.6
# soul           10.4
# groove          9.7
# hardstyle       9.6
# swedish         9.5
# dubstep         9.5
# garage          9.5
# r-n-b           8.8
# brazil          8.6
# club            8.5
# indie           8.4
# heavy-metal     8.3
# iranian         8.0
# punk-rock       8.0
# pop             7.4
# dub             7.4
# grunge          7.2
# goth            6.6
# alt-rock        5.6
# anime           5.5
# dtype: float64

# %%
most_explicit_order.dtype
# Out:
# dtype('float64')

# %%
#5. 

#Most explicit genre

print('The most explicit genre has a', most_explicit_order[0], '% likelihood of being explicit', 'and it is', most_explicit_order.index[0])
# Out:
# The most explicit genre has a 65.60000000000001 % likelihood of being explicit and it is comedy

# %%
#6. 

#How many genres have no instances of being explicit
num_nan = most_explicit_order.isnull()
#num_nan = most_explicit_order.isnull().sum()
num_nan
# Out:
# track_genre
# comedy         False
# emo            False
# sad            False
# j-dance        False
# hardcore       False
#                ...
# honky-tonk      True
# sleep           True
# study           True
# tango           True
# world-music     True
# Length: 114, dtype: bool

# %%
most_explicit_order.index
# Out:
# Index(['comedy', 'emo', 'sad', 'j-dance', 'hardcore', 'hip-hop', 'funk',
#        'dancehall', 'metalcore', 'death-metal',
#        ...
#        'pop-film', 'j-idol', 'children', 'classical', 'gospel', 'honky-tonk',
#        'sleep', 'study', 'tango', 'world-music'],
#       dtype='object', name='track_genre', length=114)

# %%
#7.

#And which ones are they? 
non_explicit_genres = most_explicit_order.loc[num_nan].index
non_explicit_genres
# Out:
# Index(['children', 'classical', 'gospel', 'honky-tonk', 'sleep', 'study',
#        'tango', 'world-music'],
#       dtype='object', name='track_genre')

# %%
#8.

#And lastly - which genres are more explicit and less explicit than the average of 8.5%?

# variable with the average = total_percent_explicit 
# series with percents = most_explicit_order


df_genre_percent = pd.DataFrame(most_explicit_order, columns = (['percent']))
df_genre_percent.reset_index(inplace = True)

df_genre_percent.head(20)
# Out:
#     track_genre  percent
# 0        comedy     65.6
# 1           emo     46.5
# 2           sad     45.0
# 3       j-dance     39.1
# 4      hardcore     32.5
# 5       hip-hop     31.9
# 6          funk     30.4
# 7     dancehall     30.2
# 8     metalcore     29.1
# 9   death-metal     25.1
# 10       latino     24.9
# 11   industrial     23.6
# 12       french     21.9
# 13      turkish     21.8
# 14    reggaeton     21.2
# 15        dance     17.4
# 16        chill     17.1
# 17       reggae     16.7
# 18  alternative     16.4
# 19      electro     15.3

# %%
filt_higher_than = (df_genre_percent['percent'] > 8.55)
df_genre_percent[filt_higher_than].head(5)
#Question: I have 8.55 written there, but can't replace it with the variable total_percent_explicit
# Out:
#   track_genre  percent
# 0      comedy     65.6
# 1         emo     46.5
# 2         sad     45.0
# 3     j-dance     39.1
# 4    hardcore     32.5

# %%
# what markuss would du (simplified of below)
df_genre_percent['is_it_average'] = df_genre_percent['percent'].apply(lambda percent: 'above_avg' if percent >= total_percent_explicit
                                                   else 'below_avg')

# %%
#Try to get an additional column on if it's above or below average, and saving it to the initial df
df_genre_percent = df_genre_percent.assign(is_it_average = df_genre_percent['percent'].apply(lambda percent: 'above_avg' if percent >= total_percent_explicit
                                                   else 'below_avg'))

# %%
df_genre_percent
# Out:
#      track_genre  percent is_it_average
# 0         comedy     65.6     above_avg
# 1            emo     46.5     above_avg
# 2            sad     45.0     above_avg
# 3        j-dance     39.1     above_avg
# 4       hardcore     32.5     above_avg
# ..           ...      ...           ...
# 109   honky-tonk      NaN     below_avg
# 110        sleep      NaN     below_avg
# 111        study      NaN     below_avg
# 112        tango      NaN     below_avg
# 113  world-music      NaN     below_avg
#
# [114 rows x 3 columns]

# %%
sns.histplot(df_genre_percent["percent"], color = '#1DB954', bins = 50, legend = True).set_title("Histo of explicitnessby genre")
plt.show()
# would like to have an average line here to show distribution but whatever for now.b

# %%
sns.boxplot(data = df_genre_percent["percent"]).set_title("Boxy p for explicit distribb")
plt.show()
#not super useful but wanted to try it out.

# %% [markdown]
# This is nothing really, just trying out a diferent histplot.

# %%
sns.histplot(df["danceability"], color = '#1DB954', bins = 50).set_title("Histo of danceability by track")
plt.show()

# %% [markdown]
# # Personal Spotify Data analysis (Your Top Songs)

# %% [markdown]
# ### Comparing the change in my Spotify top playlists over the past few years.
#
# 2022: 37i9dQZF1F0sijgNaJdgit
# 2021: spotify:playlist:37i9dQZF1EUMDoJuT8yJsl
# some are randomly not working, so the one in the dataset now is 'singing'

# %%
import json
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = '4ba78ea5e22946bc84446f9bb9ca0d9c'
client_secret = 'e9686ac736484d20a1c13ceff2c386ae'

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

playlist_id = 'spotify:playlist:3iL5Fg17rPVwZUqw4T4xCT' # singing playlist
results = sp.playlist(playlist_id)

# %%
ids=[]

for item in results['tracks']['items']:
        track = item['track']['id']
        ids.append(track)
        
song_meta={'id':[],'album':[], 'name':[], 
           'artist':[],'explicit':[],'popularity':[]}

for song_id in ids:
    # get song's meta data
    meta = sp.track(song_id)
    
    # song id
    song_meta['id'].append(song_id)

    # album name
    album=meta['album']['name']
    song_meta['album']+=[album]

    # song name
    song=meta['name']
    song_meta['name']+=[song]
    
    # artists name
    s = ', '
    artist=s.join([singer_name['name'] for singer_name in meta['artists']])
    song_meta['artist']+=[artist]
    
    # explicit: lyrics could be considered offensive or unsuitable for children
    explicit=meta['explicit']
    song_meta['explicit'].append(explicit)
    
    # song popularity
    popularity=meta['popularity']
    song_meta['popularity'].append(popularity)

song_meta_df=pd.DataFrame.from_dict(song_meta)

# check the song feature
features = sp.audio_features(song_meta['id'])
# change dictionary to dataframe
features_df=pd.DataFrame.from_dict(features)

# convert milliseconds to mins
# duration_ms: The duration of the track in milliseconds.
# 1 minute = 60 seconds = 60 × 1000 milliseconds = 60,000 ms
features_df['duration_ms']=features_df['duration_ms']/60000

# combine two dataframes
final_df=song_meta_df.merge(features_df)

# %%
final_df.head(20)
# Out:
#                         id                                       album  \
# 0   33WV1lT63pq12t9jlyrxlW            Tape Deck Heart (Deluxe Edition)
# 1   0w8URikbJO3RL4r1kiAROc      England Keep My Bones (Deluxe Edition)
# 2   0Zf5BJahvBQ6yLoCR6fPko  Music For The Motion Picture Into The Wild
# 3   300RfAPZ57B0y6YYj9n6DN                                 Number Ones
# 4   6kuqHs2ijp5D8tj0XokQQo                               A Dotted Line
# 5   1Gc7RYb9EcdkeboN5wIXtD                                  Croweology
# 6   1oT20g6f8rvymheUIdFr19       The Real Deal: Greatest Hits Volume 1
# 7   6oI3Inlpzlik5e7cy4Sdi8                               Shallow Grave
# 8   3SXsoJxUF3C9XjZnGMZbXn                               The Wild Hunt
# 9   7i5NbxA7ONWkmjtW2kXdQP                               The Wild Hunt
# 10  4NbmBhEdThmGYpiVakws47                                Made Up Mind
# 11  4W4wYHtsrgDiivRASVOINL                                Cosmic Thing
# 12  3M5eeHXgG4VplKNcsBC8Dj                 Signed Sealed And Delivered
# 13  0PoAZGBHq7hNthe0mma0bO                        Hand Built By Robots
# 14  6Qyc6fS4DsZjB2mRW9DsQs                           Dizzy up the Girl
# 15  7lrDNvF3TwuC5vC2fGiMjy                        Dream Your Life Away
# 16  6pxElwU80zhjbCC77Vn8EI                                   Geography
# 17  7BDbyDs5FUmnh955RABFd7                            Free Yourself Up
# 18  65EVlEBJkMJCskhQwUUGew                          Bad Self Portraits
# 19  0hKF8N8aflF1uDzEEnPr2j                               Mad Mad World
#
#                                      name                    artist  explicit  \
# 0                    The Way I Tend To Be              Frank Turner     False
# 1                    Peggy Sang The Blues              Frank Turner     False
# 2                                Hard Sun              Eddie Vedder     False
# 3           Superstition - Single Version             Stevie Wonder     False
# 4                             Destination              Nickel Creek     False
# 5                            Soul Singing          The Black Crowes     False
# 6                           Pride and Joy        Stevie Ray Vaughan     False
# 7                            The Gardener  The Tallest Man On Earth     False
# 8                           King of Spain  The Tallest Man On Earth     False
# 9                           The Wild Hunt  The Tallest Man On Earth     False
# 10                     Calling Out To You      Tedeschi Trucks Band     False
# 11                             Love Shack                The B-52's     False
# 12  Signed, Sealed, Delivered (I'm Yours)             Stevie Wonder     False
# 13                               Teardrop           Newton Faulkner     False
# 14                                   Iris         The Goo Goo Dolls     False
# 15                           Mess Is Mine                 Vance Joy     False
# 16                                  Movie                 Tom Misch     False
# 17                            Good Kisser          Lake Street Dive     False
# 18                     You Go Down Smooth          Lake Street Dive     False
# 19                      Life Is A Highway              Tom Cochrane     False
#
#     popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0           45         0.583   0.911   11    -3.579     1       0.0344
# 1           33         0.585   0.768    0    -5.254     1       0.0346
# 2            0         0.441   0.828    8    -6.544     1       0.0331
# 3            5         0.642   0.735    8    -8.866     1       0.0806
# 4           46         0.515   0.444    0    -8.847     0       0.0296
# 5            0         0.375   0.623    5   -11.422     1       0.0369
# 6           51         0.426   0.693    8    -9.759     1       0.0377
# 7            0         0.496   0.533    3    -4.979     0       0.0264
# 8            0         0.385   0.493    8    -8.342     1       0.0344
# 9            0         0.569   0.397    9   -10.183     1       0.0302
# 10          40         0.597   0.118    6   -13.908     1       0.0358
# 11          70         0.701   0.803    5    -6.786     0       0.0545
# 12           0         0.670   0.619    0   -10.365     0       0.0323
# 13          12         0.552   0.213    6   -13.522     1       0.0285
# 14          83         0.315   0.715   11    -8.072     0       0.0362
# 15           0         0.595   0.723    7    -8.256     1       0.0349
# 16          18         0.785   0.379    7   -11.446     1       0.0732
# 17          60         0.485   0.591   10    -3.888     1       0.0453
# 18          53         0.314   0.787    4    -4.838     1       0.0771
# 19          60         0.683   0.751    5   -10.184     1       0.0346
#
#     acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.14000          0.000000    0.2730    0.826   86.177
# 1        0.04660          0.000000    0.1010    0.638   91.033
# 2        0.05330          0.000328    0.3250    0.643  143.395
# 3        0.01720          0.000733    0.0391    0.864   99.682
# 4        0.46000          0.000038    0.1000    0.692  145.900
# 5        0.03880          0.000083    0.2160    0.590  169.014
# 6        0.02510          0.006500    0.1010    0.751  126.804
# 7        0.92800          0.000000    0.1310    0.415   95.477
# 8        0.75700          0.000002    0.1160    0.375  131.615
# 9        0.85000          0.000002    0.1100    0.520  101.116
# 10       0.96400          0.001320    0.1120    0.316  102.067
# 11       0.05440          0.000002    0.7000    0.903  133.608
# 12       0.05140          0.000000    0.0492    0.807  108.826
# 13       0.79600          0.000018    0.1330    0.161   74.968
# 14       0.00125          0.000008    0.0942    0.497  155.925
# 15       0.04700          0.028600    0.0995    0.272  108.043
# 16       0.39100          0.016100    0.2670    0.182  122.043
# 17       0.11900          0.002780    0.0787    0.636  160.336
# 18       0.07120          0.000023    0.1600    0.294  189.901
# 19       0.06810          0.000008    0.2480    0.841  103.036
#
#               type                                   uri  \
# 0   audio_features  spotify:track:33WV1lT63pq12t9jlyrxlW
# 1   audio_features  spotify:track:0w8URikbJO3RL4r1kiAROc
# 2   audio_features  spotify:track:0Zf5BJahvBQ6yLoCR6fPko
# 3   audio_features  spotify:track:300RfAPZ57B0y6YYj9n6DN
# 4   audio_features  spotify:track:6kuqHs2ijp5D8tj0XokQQo
# 5   audio_features  spotify:track:1Gc7RYb9EcdkeboN5wIXtD
# 6   audio_features  spotify:track:1oT20g6f8rvymheUIdFr19
# 7   audio_features  spotify:track:6oI3Inlpzlik5e7cy4Sdi8
# 8   audio_features  spotify:track:3SXsoJxUF3C9XjZnGMZbXn
# 9   audio_features  spotify:track:7i5NbxA7ONWkmjtW2kXdQP
# 10  audio_features  spotify:track:4NbmBhEdThmGYpiVakws47
# 11  audio_features  spotify:track:4W4wYHtsrgDiivRASVOINL
# 12  audio_features  spotify:track:3M5eeHXgG4VplKNcsBC8Dj
# 13  audio_features  spotify:track:0PoAZGBHq7hNthe0mma0bO
# 14  audio_features  spotify:track:6Qyc6fS4DsZjB2mRW9DsQs
# 15  audio_features  spotify:track:7lrDNvF3TwuC5vC2fGiMjy
# 16  audio_features  spotify:track:6pxElwU80zhjbCC77Vn8EI
# 17  audio_features  spotify:track:7BDbyDs5FUmnh955RABFd7
# 18  audio_features  spotify:track:65EVlEBJkMJCskhQwUUGew
# 19  audio_features  spotify:track:0hKF8N8aflF1uDzEEnPr2j
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/33WV1lT63pq1...
# 1   https://api.spotify.com/v1/tracks/0w8URikbJO3R...
# 2   https://api.spotify.com/v1/tracks/0Zf5BJahvBQ6...
# 3   https://api.spotify.com/v1/tracks/300RfAPZ57B0...
# 4   https://api.spotify.com/v1/tracks/6kuqHs2ijp5D...
# 5   https://api.spotify.com/v1/tracks/1Gc7RYb9Ecdk...
# 6   https://api.spotify.com/v1/tracks/1oT20g6f8rvy...
# 7   https://api.spotify.com/v1/tracks/6oI3Inlpzlik...
# 8   https://api.spotify.com/v1/tracks/3SXsoJxUF3C9...
# 9   https://api.spotify.com/v1/tracks/7i5NbxA7ONWk...
# 10  https://api.spotify.com/v1/tracks/4NbmBhEdThmG...
# 11  https://api.spotify.com/v1/tracks/4W4wYHtsrgDi...
# 12  https://api.spotify.com/v1/tracks/3M5eeHXgG4Vp...
# 13  https://api.spotify.com/v1/tracks/0PoAZGBHq7hN...
# 14  https://api.spotify.com/v1/tracks/6Qyc6fS4DsZj...
# 15  https://api.spotify.com/v1/tracks/7lrDNvF3TwuC...
# 16  https://api.spotify.com/v1/tracks/6pxElwU80zhj...
# 17  https://api.spotify.com/v1/tracks/7BDbyDs5FUmn...
# 18  https://api.spotify.com/v1/tracks/65EVlEBJkMJC...
# 19  https://api.spotify.com/v1/tracks/0hKF8N8aflF1...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/33WV...     3.688217
# 1   https://api.spotify.com/v1/audio-analysis/0w8U...     3.546217
# 2   https://api.spotify.com/v1/audio-analysis/0Zf5...     5.362667
# 3   https://api.spotify.com/v1/audio-analysis/300R...     4.080450
# 4   https://api.spotify.com/v1/audio-analysis/6kuq...     3.854000
# 5   https://api.spotify.com/v1/audio-analysis/1Gc7...     4.251783
# 6   https://api.spotify.com/v1/audio-analysis/1oT2...     3.664000
# 7   https://api.spotify.com/v1/audio-analysis/6oI3...     3.950000
# 8   https://api.spotify.com/v1/audio-analysis/3SXs...     3.436450
# 9   https://api.spotify.com/v1/audio-analysis/7i5N...     3.360000
# 10  https://api.spotify.com/v1/audio-analysis/4Nbm...     3.769333
# 11  https://api.spotify.com/v1/audio-analysis/4W4w...     5.344667
# 12  https://api.spotify.com/v1/audio-analysis/3M5e...     2.675000
# 13  https://api.spotify.com/v1/audio-analysis/0PoA...     3.149117
# 14  https://api.spotify.com/v1/audio-analysis/6Qyc...     4.825550
# 15  https://api.spotify.com/v1/audio-analysis/7lrD...     3.727333
# 16  https://api.spotify.com/v1/audio-analysis/6pxE...     5.955950
# 17  https://api.spotify.com/v1/audio-analysis/7BDb...     3.641550
# 18  https://api.spotify.com/v1/audio-analysis/65EV...     3.490000
# 19  https://api.spotify.com/v1/audio-analysis/0hKF...     4.442667
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# 8                4
# 9                4
# 10               4
# 11               4
# 12               4
# 13               4
# 14               3
# 15               1
# 16               3
# 17               4
# 18               4
# 19               4

# %%
music_feature=final_df[['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness'
                          , 'valence', 'tempo', 'duration_ms']]
print(music_feature)
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.583   0.911    -3.579       0.0344       0.14000
# 1          0.585   0.768    -5.254       0.0346       0.04660
# 2          0.441   0.828    -6.544       0.0331       0.05330
# 3          0.642   0.735    -8.866       0.0806       0.01720
# 4          0.515   0.444    -8.847       0.0296       0.46000
# 5          0.375   0.623   -11.422       0.0369       0.03880
# 6          0.426   0.693    -9.759       0.0377       0.02510
# 7          0.496   0.533    -4.979       0.0264       0.92800
# 8          0.385   0.493    -8.342       0.0344       0.75700
# 9          0.569   0.397   -10.183       0.0302       0.85000
# 10         0.597   0.118   -13.908       0.0358       0.96400
# 11         0.701   0.803    -6.786       0.0545       0.05440
# 12         0.670   0.619   -10.365       0.0323       0.05140
# 13         0.552   0.213   -13.522       0.0285       0.79600
# 14         0.315   0.715    -8.072       0.0362       0.00125
# 15         0.595   0.723    -8.256       0.0349       0.04700
# 16         0.785   0.379   -11.446       0.0732       0.39100
# 17         0.485   0.591    -3.888       0.0453       0.11900
# 18         0.314   0.787    -4.838       0.0771       0.07120
# 19         0.683   0.751   -10.184       0.0346       0.06810
# 20         0.839   0.585    -7.738       0.1530       0.47800
# 21         0.729   0.551    -7.361       0.2680       0.71200
# 22         0.633   0.754    -6.495       0.0382       0.03160
# 23         0.601   0.574    -8.166       0.0300       0.57900
# 24         0.621   0.403    -8.211       0.0359       0.58100
# 25         0.842   0.697   -13.796       0.0654       0.16100
# 26         0.542   0.588    -7.961       0.0772       0.48800
#
#     instrumentalness  liveness  valence    tempo  duration_ms
# 0           0.000000    0.2730    0.826   86.177     3.688217
# 1           0.000000    0.1010    0.638   91.033     3.546217
# 2           0.000328    0.3250    0.643  143.395     5.362667
# 3           0.000733    0.0391    0.864   99.682     4.080450
# 4           0.000038    0.1000    0.692  145.900     3.854000
# 5           0.000083    0.2160    0.590  169.014     4.251783
# 6           0.006500    0.1010    0.751  126.804     3.664000
# 7           0.000000    0.1310    0.415   95.477     3.950000
# 8           0.000002    0.1160    0.375  131.615     3.436450
# 9           0.000002    0.1100    0.520  101.116     3.360000
# 10          0.001320    0.1120    0.316  102.067     3.769333
# 11          0.000002    0.7000    0.903  133.608     5.344667
# 12          0.000000    0.0492    0.807  108.826     2.675000
# 13          0.000018    0.1330    0.161   74.968     3.149117
# 14          0.000008    0.0942    0.497  155.925     4.825550
# 15          0.028600    0.0995    0.272  108.043     3.727333
# 16          0.016100    0.2670    0.182  122.043     5.955950
# 17          0.002780    0.0787    0.636  160.336     3.641550
# 18          0.000023    0.1600    0.294  189.901     3.490000
# 19          0.000008    0.2480    0.841  103.036     4.442667
# 20          0.002810    0.0435    0.890   89.821     3.021000
# 21          0.000081    0.1210    0.435   87.910     4.818467
# 22          0.000023    0.0910    0.641  137.047     3.645117
# 23          0.000011    0.2160    0.800  147.964     3.568000
# 24          0.000000    0.1140    0.634  145.523     3.868883
# 25          0.000101    0.5830    0.916  134.533     4.453783
# 26          0.000133    0.1590    0.542   87.003     3.771317

# %%
type(music_feature)
# Out:
# pandas.core.frame.DataFrame

# %%
music_feature.describe()
# Out:
#        danceability     energy   loudness  speechiness  acousticness  \
# count     27.000000  27.000000  27.000000    27.000000     27.000000
# mean       0.574852   0.602815  -8.472889     0.055481      0.329998
# std        0.142590   0.188076   2.814412     0.050237      0.332582
# min        0.314000   0.118000 -13.908000     0.026400      0.001250
# 25%        0.490500   0.513000 -10.183500     0.033750      0.049200
# 50%        0.585000   0.619000  -8.211000     0.035900      0.140000
# 75%        0.656000   0.743000  -6.665000     0.059950      0.580000
# max        0.842000   0.911000  -3.579000     0.268000      0.964000
#
#        instrumentalness   liveness    valence       tempo  duration_ms
# count         27.000000  27.000000  27.000000   27.000000    27.000000
# mean           0.002211   0.177081   0.595593  121.435815     3.976352
# std            0.006219   0.153228   0.228499   29.718340     0.754527
# min            0.000000   0.039100   0.161000   74.968000     2.675000
# 25%            0.000002   0.099750   0.425000   97.579500     3.557108
# 50%            0.000023   0.116000   0.636000  122.043000     3.769333
# 75%            0.000531   0.216000   0.803500  144.459000     4.347225
# max            0.028600   0.700000   0.916000  189.901000     5.955950

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
music_feature=scaler.fit_transform(music_feature)

# %%
print(type(music_feature))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# Could also possibly have used a lamda for rescale as seen here: https://www.python-graph-gallery.com/web-radar-chart-with-matplotlib

# %%
print(list(music_feature))
music_feature = pd.DataFrame(music_feature)
music_feature.reset_index
music_feature.head()
# Out:
# [array([0.5094697 , 1.        , 1.        , 0.03311258, 0.14411841,
#        0.        , 0.35391133, 0.8807947 , 0.09752638, 0.30881808]), array([0.51325758, 0.81967213, 0.83783522, 0.0339404 , 0.04710465,
#        0.        , 0.09366016, 0.63178808, 0.13977709, 0.26553793]), array([0.2405303 , 0.89533417, 0.71294414, 0.02773179, 0.05406388,
#        0.01146853, 0.43259192, 0.6384106 , 0.59536426, 0.81917331]), array([0.62121212, 0.77805801, 0.48814019, 0.22433775, 0.01656713,
#        0.02562937, 0.        , 0.93112583, 0.21502963, 0.42836678]), array([0.38068182, 0.4110971 , 0.48997967, 0.01324503, 0.47649961,
#        0.00133217, 0.09214707, 0.70331126, 0.61715956, 0.35934714]), array([0.1155303 , 0.63682219, 0.24068158, 0.04346026, 0.03900286,
#        0.00291958, 0.2676653 , 0.56821192, 0.81826803, 0.48058743]), array([0.21212121, 0.72509458, 0.40168458, 0.04677152, 0.02477279,
#        0.22727273, 0.09366016, 0.78145695, 0.45101059, 0.30143708]), array([0.34469697, 0.52332913, 0.86445929, 0.        , 0.96260712,
#        0.        , 0.13905281, 0.33642384, 0.17844309, 0.38860696]), array([1.34469697e-01, 4.72887768e-01, 5.38871140e-01, 3.31125828e-02,
#        7.84990911e-01, 8.56643357e-05, 1.16356484e-01, 2.83443709e-01,
#        4.92869759e-01, 2.32082171e-01]), array([4.82954545e-01, 3.51828499e-01, 3.60635105e-01, 1.57284768e-02,
#        8.81589198e-01, 6.46853147e-05, 1.07277954e-01, 4.75496689e-01,
#        2.27506460e-01, 2.08780993e-01]), array([0.53598485, 0.        , 0.        , 0.03890728, 1.        ,
#        0.04615385, 0.11030413, 0.20529801, 0.23578085, 0.33354161]), array([7.32954545e-01, 8.63808323e-01, 6.89514958e-01, 1.16307947e-01,
#        5.52064399e-02, 5.38461538e-05, 1.00000000e+00, 9.82781457e-01,
#        5.10210296e-01, 8.13687093e-01]), array([0.67424242, 0.63177806, 0.34301481, 0.02442053, 0.05209037,
#        0.        , 0.01528219, 0.85562914, 0.29458902, 0.        ]), array([4.50757576e-01, 1.19798235e-01, 3.73705102e-02, 8.69205298e-03,
#        8.25499870e-01, 6.32867133e-04, 1.42078983e-01, 0.00000000e+00,
#        0.00000000e+00, 1.44505910e-01]), array([1.89393939e-03, 7.52837327e-01, 5.65011134e-01, 4.05629139e-02,
#        0.00000000e+00, 2.78671329e-04, 8.33711605e-02, 4.45033113e-01,
#        7.04384293e-01, 6.55465643e-01]), array([0.53219697, 0.7629256 , 0.54719721, 0.03518212, 0.04752012,
#        1.        , 0.09139053, 0.14701987, 0.28777636, 0.32074044]), array([0.89204545, 0.32912989, 0.23835802, 0.19370861, 0.40482991,
#        0.56293706, 0.3448328 , 0.02781457, 0.40958645, 1.        ]), array([0.32386364, 0.5964691 , 0.97008423, 0.07822848, 0.12230589,
#        0.0972028 , 0.05991829, 0.62913907, 0.74276318, 0.29459455]), array([0.00000000e+00, 8.43631778e-01, 8.78110175e-01, 2.09850993e-01,
#        7.26564529e-02, 7.86713287e-04, 1.82932365e-01, 1.76158940e-01,
#        1.00000000e+00, 2.48403664e-01]), array([6.98863636e-01, 7.98234552e-01, 3.60538290e-01, 3.39403974e-02,
#        6.94365100e-02, 2.92307692e-04, 3.16084128e-01, 9.00662252e-01,
#        2.44211845e-01, 5.38766719e-01]), array([0.99431818, 0.5889029 , 0.59734727, 0.52400662, 0.49519605,
#        0.09825175, 0.00665759, 0.96556291, 0.12923181, 0.10545726]), array([0.78598485, 0.54602774, 0.63384645, 1.        , 0.73824981,
#        0.00281818, 0.12392192, 0.36291391, 0.11260473, 0.65330672]), array([6.04166667e-01, 8.02017654e-01, 7.17688063e-01, 4.88410596e-02,
#        3.15242794e-02, 7.93706294e-04, 7.85292783e-02, 6.35761589e-01,
#        5.40132077e-01, 2.95681637e-01]), array([5.43560606e-01, 5.75031526e-01, 5.55910543e-01, 1.49006623e-02,
#        6.00103869e-01, 3.98601399e-04, 2.67665305e-01, 8.46357616e-01,
#        6.35117851e-01, 2.72177266e-01]), array([0.58143939, 0.3593947 , 0.55155388, 0.03932119, 0.60218125,
#        0.        , 0.11333031, 0.62649007, 0.61387939, 0.36388343]), array([1.        , 0.73013871, 0.01084326, 0.16142384, 0.16593093,
#        0.00353147, 0.82296868, 1.        , 0.51825846, 0.54215497]), array([0.43181818, 0.592686  , 0.57575758, 0.2102649 , 0.50558297,
#        0.00465035, 0.18141928, 0.50463576, 0.10471318, 0.33414611])]
#           0         1         2         3         4         5         6  \
# 0  0.509470  1.000000  1.000000  0.033113  0.144118  0.000000  0.353911
# 1  0.513258  0.819672  0.837835  0.033940  0.047105  0.000000  0.093660
# 2  0.240530  0.895334  0.712944  0.027732  0.054064  0.011469  0.432592
# 3  0.621212  0.778058  0.488140  0.224338  0.016567  0.025629  0.000000
# 4  0.380682  0.411097  0.489980  0.013245  0.476500  0.001332  0.092147
#
#           7         8         9
# 0  0.880795  0.097526  0.308818
# 1  0.631788  0.139777  0.265538
# 2  0.638411  0.595364  0.819173
# 3  0.931126  0.215030  0.428367
# 4  0.703311  0.617160  0.359347

# %%
import math
print(math.pi)
pi = (math.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# Found out after doing the above that numpy already has pi saved. So can just:
# np.pi
# Ah well.

# %%
#This code is taken from here: https://towardsdatascience.com/discovering-your-music-taste-with-python-and-spotify-api-b51b0d2744d
#It's not very beautiful and there's a fair bit missing so I have edited it quite a lot as mine does not look like the one in the example!
# plot size
fig=plt.figure(figsize=(12,8))

# convert column names into a list
categories=list(music_feature.columns)
# number of categories
N=len(categories)

# create a list with the average of all features
value=list(music_feature.mean())

# repeat first value to close the circle
# the plot is a circle, so we need to "complete the loop"
# and append the start value to the end.
value+=value[:1]
# calculate angle for each category
angles=[n/float(N)*2*pi for n in range(N)]
angles+=angles[:1]

# plot
plt.polar(angles, value)
plt.fill(angles,value,alpha=0.3)

plt.title('"For Singing" Songs Audio Features', size=35)

plt.xticks(angles[:-1],categories, size=15)
plt.yticks(color='#1DB954',size=15)
plt.show()

# %% [markdown]
# I tried a bunch of other things and none of it worked, so going back to trying to customise the one above - the screenshot from the tutorial shows labels of the lategory, but
